# %% [markdown]
# # File Setup

# %%
# Import dependencies
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup as bs
from webdriver_manager.chrome import ChromeDriverManager

# %% [markdown]
# # Scraping

# %%
# Importing user input data
with open('../Input/URL.txt', 'r') as input_data:
    for line in input_data:
        url = line

# %%
# Connecting to site
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
# Driver [C:\Users\Chrismus Time\.wdm\drivers\chromedriver\win32\97.0.4692.71\chromedriver.exe] found in cache

# %%
# Visiting site
browser.visit(url)

# Fetch raw html, parse into BS object
soup = bs(browser.html, 'html.parser')

# Click the privacy agree button
# browser.click_link_by_id('div[class=" css-47sehv"]')
# ------- NEED TO CLICK THE ACCEPT BUTTON HERE -----------

# %%
# Create storage variables for building df
all_df_headers = ['Champion']
all_champ_data = []
is_first_champion = True

# %%
# Scrape every champion row from BS object
champ_rows = soup.find_all('div', class_ = 'row champion-table__row')
for champ in champ_rows:
    # Temp storage variables
    curr_champ_data = []

    # Scrape champion name
    curr_name = champ.find('div', class_ = 'row__champion__name').text
    curr_champ_data.append(curr_name)

    # Click to reveal statistics (but only if its not the first champion because site comes loaded with stats revealed for first champion)
    if is_first_champion == False:
        target = 'div[class="row champion-table__row"]'
        browser.find_by_tag(target).click()
        # ------- NEED A WAIT TIMER HERE ----------- 
    
    # Scrape every statistic per champion
    statistics = champ.find_all('div', class_ = 'column col-2 col-sm-4')
    for stat in statistics:
        # Scrape statistic header (but only if its the first champion)
        if is_first_champion == True:    
            curr_header = stat.find('div', class_='percentile-stat__label text-ellipsis text-uppercase').text.strip()
            if curr_header not in all_df_headers:
                all_df_headers.append(curr_header)

        # Scrap statistic value
        curr_value = stat.find('div', class_='percentile-stat__value c-help col-11').text.strip()
        curr_champ_data.append(curr_value)
    
    # Append finished champ data list to mega list
    all_champ_data.append(curr_champ_data)

    # Adjust boolean so no longer scrap header for all subsequent champions (since all champs will have same statistics headers)
    is_first_champion = False

# Close browser when done
browser.quit()
# Out:
# ---
# Jenos
# 11h 27m
# 255,447
# 372
# 4.94
# 635
# 292
# 1,615
# 2,999,280
# 4,366
# 2,626,650
# 1,953,941
# 0
# 3,198,972
# 748,485
# 42m 35s
# 61
# 18
# 77.22%
# ---
# Yagorath
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# C:\Users\CHRISM~1\AppData\Local\Temp/ipykernel_37692/4040384842.py in <module>
#      25     if is_first_champion == False:
#      26         target = 'div[class="row champion-table__row"]'
# ---> 27         browser.find_by_tag(target).click()
#      28
#      29
#
# ~\anaconda3\envs\PythonData\lib\site-packages\splinter\driver\webdriver\__init__.py in click(self)
#     823                 error = e
#     824
# --> 825         raise error
#     826
#     827     def check(self):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\splinter\driver\webdriver\__init__.py in click(self)
#     816         while time.time() < end_time:
#     817             try:
# --> 818                 return self._element.click()
#     819             except(
#     820                 ElementClickInterceptedException,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\envs\PythonData\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementClickInterceptedException: Message: element click intercepted: Element <div class="row champion-table__row" data-v-13192073="" data-v-1c535d7c="">...</div> is not clickable at point (456, 783). Other element would receive the click: <div height="897" class="qc-cmp-cleanslate css-1ehl0k6">...</div>
#   (Session info: chrome=97.0.4692.71)

# %%
#browser.links.find_by_partial_text('Next').click()

# %% [markdown]
# # Dataframe Creation

# %%
# Create dataframe
df = pd.DataFrame(all_champ_data, columns = all_df_headers)
df
# Out:
#      Champion playtime  Credits   CPM   kda kills deaths assists     damage  \
# 0       Jenos  11h 27m  255,447   372  4.94   635    292   1,615  2,999,280
# 1    Yagorath     None     None  None  None  None   None    None       None
# 2       Strix     None     None  None  None  None   None    None       None
# 3       Talus     None     None  None  None  None   None    None       None
# 4       Barik     None     None  None  None  None   None    None       None
# 5         Ash     None     None  None  None  None   None    None       None
# 6    Androxus     None     None  None  None  None   None    None       None
# 7     Sha Lin     None     None  None  None  None   None    None       None
# 8      Viktor     None     None  None  None  None   None    None       None
# 9        Lian     None     None  None  None  None   None    None       None
# 10    Kinessa     None     None  None  None  None   None    None       None
# 11        Lex     None     None  None  None  None   None    None       None
# 12       Vatu     None     None  None  None  None   None    None       None
# 13      Maeve     None     None  None  None  None   None    None       None
# 14      Inara     None     None  None  None  None   None    None       None
# 15  Bomb King     None     None  None  None  None   None    None       None
# 16         Io     None     None  None  None  None   None    None       None
# 17  Mal'Damba     None     None  None  None  None   None    None       None
# 18   Fernando     None     None  None  None  None   None    None       None
# 19   Terminus     None     None  None  None  None   None    None       None
# 20       Moji     None     None  None  None  None   None    None       None
# 21   Tiberius     None     None  None  None  None   None    None       None
# 22      Makoa     None     None  None  None  None   None    None       None
# 23     Corvus     None     None  None  None  None   None    None       None
# 24     Cassie     None     None  None  None  None   None    None       None
# 25       Buck     None     None  None  None  None   None    None       None
# 26       Ying     None     None  None  None  None   None    None       None
# 27       Skye     None     None  None  None  None   None    None       None
# 28      Willo     None     None  None  None  None   None    None       None
# 29       Khan     None     None  None  None  None   None    None       None
# 30      Atlas     None     None  None  None  None   None    None       None
# 31    Octavia     None     None  None  None  None   None    None       None
# 32       Tyra     None     None  None  None  None   None    None       None
# 33       Evie     None     None  None  None  None   None    None       None
# 34      Furia     None     None  None  None  None   None    None       None
# 35      Imani     None     None  None  None  None   None    None       None
# 36        Pip     None     None  None  None  None   None    None       None
# 37     Ruckus     None     None  None  None  None   None    None       None
# 38       Zhin     None     None  None  None  None   None    None       None
# 39      Seris     None     None  None  None  None   None    None       None
# 40      Grohk     None     None  None  None  None   None    None       None
# 41     Grover     None     None  None  None  None   None    None       None
# 42     Drogoz     None     None  None  None  None   None    None       None
# 43    Torvald     None     None  None  None  None   None    None       None
# 44     Vivian     None     None  None  None  None   None    None       None
# 45       Koga     None     None  None  None  None   None    None       None
# 46     Dredge     None     None  None  None  None   None    None       None
# 47       Raum     None     None  None  None  None   None    None       None
# 48       Vora     None     None  None  None  None   None    None       None
#
#       dpm     Weapon      taken Shielding    healing self healing  \
# 0   4,366  2,626,650  1,953,941         0  3,198,972      748,485
# 1    None       None       None      None       None         None
# 2    None       None       None      None       None         None
# 3    None       None       None      None       None         None
# 4    None       None       None      None       None         None
# 5    None       None       None      None       None         None
# 6    None       None       None      None       None         None
# 7    None       None       None      None       None         None
# 8    None       None       None      None       None         None
# 9    None       None       None      None       None         None
# 10   None       None       None      None       None         None
# 11   None       None       None      None       None         None
# 12   None       None       None      None       None         None
# 13   None       None       None      None       None         None
# 14   None       None       None      None       None         None
# 15   None       None       None      None       None         None
# 16   None       None       None      None       None         None
# 17   None       None       None      None       None         None
# 18   None       None       None      None       None         None
# 19   None       None       None      None       None         None
# 20   None       None       None      None       None         None
# 21   None       None       None      None       None         None
# 22   None       None       None      None       None         None
# 23   None       None       None      None       None         None
# 24   None       None       None      None       None         None
# 25   None       None       None      None       None         None
# 26   None       None       None      None       None         None
# 27   None       None       None      None       None         None
# 28   None       None       None      None       None         None
# 29   None       None       None      None       None         None
# 30   None       None       None      None       None         None
# 31   None       None       None      None       None         None
# 32   None       None       None      None       None         None
# 33   None       None       None      None       None         None
# 34   None       None       None      None       None         None
# 35   None       None       None      None       None         None
# 36   None       None       None      None       None         None
# 37   None       None       None      None       None         None
# 38   None       None       None      None       None         None
# 39   None       None       None      None       None         None
# 40   None       None       None      None       None         None
# 41   None       None       None      None       None         None
# 42   None       None       None      None       None         None
# 43   None       None       None      None       None         None
# 44   None       None       None      None       None         None
# 45   None       None       None      None       None         None
# 46   None       None       None      None       None         None
# 47   None       None       None      None       None         None
# 48   None       None       None      None       None         None
#
#    objective time  wins losses Win/Loss Ratio
# 0         42m 35s    61     18         77.22%
# 1            None  None   None           None
# 2            None  None   None           None
# 3            None  None   None           None
# 4            None  None   None           None
# 5            None  None   None           None
# 6            None  None   None           None
# 7            None  None   None           None
# 8            None  None   None           None
# 9            None  None   None           None
# 10           None  None   None           None
# 11           None  None   None           None
# 12           None  None   None           None
# 13           None  None   None           None
# 14           None  None   None           None
# 15           None  None   None           None
# 16           None  None   None           None
# 17           None  None   None           None
# 18           None  None   None           None
# 19           None  None   None           None
# 20           None  None   None           None
# 21           None  None   None           None
# 22           None  None   None           None
# 23           None  None   None           None
# 24           None  None   None           None
# 25           None  None   None           None
# 26           None  None   None           None
# 27           None  None   None           None
# 28           None  None   None           None
# 29           None  None   None           None
# 30           None  None   None           None
# 31           None  None   None           None
# 32           None  None   None           None
# 33           None  None   None           None
# 34           None  None   None           None
# 35           None  None   None           None
# 36           None  None   None           None
# 37           None  None   None           None
# 38           None  None   None           None
# 39           None  None   None           None
# 40           None  None   None           None
# 41           None  None   None           None
# 42           None  None   None           None
# 43           None  None   None           None
# 44           None  None   None           None
# 45           None  None   None           None
# 46           None  None   None           None
# 47           None  None   None           None
# 48           None  None   None           None

# %%
# Importing champion list
with open('../Input/Champions List.txt', 'r') as input_data:
    all_champs = [line.strip() for line in input_data]

# Creating Pandas dataframe to hold all scraped data
# df = pd.DataFrame(all_champs, columns = ['Champion']).sort_values('Champion').reset_index().drop('index', axis = 1)
# df = pd.DataFrame()
